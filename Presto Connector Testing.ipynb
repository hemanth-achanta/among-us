# %%
import pandas as pd
# import presto
import prestodb

# %%
# Connection Details
# host = 'hue-dp-emr-prod-adhoc-procurement-analytics.private.dataplatform.link'
# host = 'pe-analytics-adhoc.private.dataplatform.link'
# host = 'hue.prod.apianalytics.in'
host = 'metabase-trino-master.prod.dataplatform.link'
port = '8443'
user = 'hemanth.achanta'
password = 'Hey@12345'



#   host: ''
#   port: 8443
#   username: ''
#   password: ''
#   catalog: 'lakehouse'

# %%
# Creating Connection and Initializing Cursor

def presto_connection(host, port, user):
    try:
        conn = prestodb.dbapi.connect(host=host,
                                      port=port,
                                      user=user,
                                      http_scheme="https",
                                      auth=prestodb.auth.BasicAuthentication(user, password),
                                      )
        # isolation_level=transaction.IsolationLevel.REPEATABLE_READ)
    except Exception as e:
        print(str(e))
    return conn


# Function for Retrieving Dataframe using Presto Connection
def df_from_presto(query):
    df = pd.DataFrame()
    try:
        print("Establishing Connection")
        conn = presto_connection(host, port, user)
        conn._http_session.verify = False
        print("Connected")
        cursor = conn.cursor()
        print("Starting Query Execution")
        cursor.execute(query)
        records = cursor.fetchall()
        print("Query Executed")
        column_descriptions = cursor.description
        df = pd.DataFrame(records)
        df.columns = [c[0] for c in column_descriptions]
        # print(df)
        conn.close()
        print("Connection Closed")
    except Exception as e:
        print("Error Message: ", str(e))
    return df

# %%
nrs = """
SELECT * FROM hive.data_model.doc_consult_orders LIMIT 10
"""

# %%
nrs_data = df_from_presto(nrs)
# Out:
# Establishing Connection
# Connected
# Starting Query Execution
# /opt/anaconda3/envs/AI_env/lib/python3.13/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'metabase-trino-master.prod.dataplatform.link'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /opt/anaconda3/envs/AI_env/lib/python3.13/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'metabase-trino-master.prod.dataplatform.link'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /opt/anaconda3/envs/AI_env/lib/python3.13/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'metabase-trino-master.prod.dataplatform.link'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /opt/anaconda3/envs/AI_env/lib/python3.13/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'metabase-trino-master.prod.dataplatform.link'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Query Executed
# Connection Closed
# /opt/anaconda3/envs/AI_env/lib/python3.13/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'metabase-trino-master.prod.dataplatform.link'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /opt/anaconda3/envs/AI_env/lib/python3.13/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'metabase-trino-master.prod.dataplatform.link'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %%
nrs_data
# Out:
#              order_id  parent_id          order_placed_at order_placed_date  \
# 0  682106507122552832   36900596  2026-02-16 00:16:44.209        2026-02-16
# 1  682107391466385408   36900634  2026-02-16 00:20:15.056        2026-02-16
# 2  682109157893320704   36900711  2026-02-16 00:27:16.115        2026-02-16
# 3  682110245438599168   36900748  2026-02-16 00:31:35.463        2026-02-16
# 4  682114647609913344   36900952  2026-02-16 00:49:05.054        2026-02-16
# 5  682116111317151744   36900999  2026-02-16 00:54:54.033        2026-02-16
# 6  682132028381290496   36901327  2026-02-16 01:58:08.952        2026-02-16
# 7  682176794519232512   36901708  2026-02-16 04:56:01.928        2026-02-16
# 8  682181562591436800   36901739  2026-02-16 05:14:58.822        2026-02-16
# 9  682188198055862272   36901790  2026-02-16 05:41:20.850        2026-02-16
#
#   customer_id    order_source attributes_vertical order_status delivered_date  \
# 0    50030311  Mobile_Website        CONSULTATION    CANCELLED           None
# 1    50030311  Mobile_Website        CONSULTATION    COMPLETED     2026-02-16
# 2     3686513     Android_App        CONSULTATION    COMPLETED     2026-02-16
# 3     3975170  Mobile_Website        CONSULTATION    COMPLETED     2026-02-16
# 4     8052767         iOS_App        CONSULTATION    COMPLETED     2026-02-16
# 5    44419268         iOS_App        CONSULTATION    COMPLETED     2026-02-18
# 6    22731693         iOS_App        CONSULTATION    CANCELLED           None
# 7     6666522     Android_App        CONSULTATION    CANCELLED           None
# 8    55314757  Mobile_Website        CONSULTATION    COMPLETED     2026-02-16
# 9     4257546  Mobile_Website        CONSULTATION    CANCELLED           None
#
#    placed_mrp  ...  diag_status  consult_status  digi_flag  crosssold_status  \
# 0       349.0  ...         None     Consult New          0               New
# 1       349.0  ...         None     Consult New          1               New
# 2       349.0  ...         None     Consult New          0               Old
# 3       349.0  ...         None     Consult New          1               Old
# 4       349.0  ...         None     Consult Old          0               New
# 5       349.0  ...     Diag_Old     Consult New          0               Old
# 6       349.0  ...         None     Consult New          0               New
# 7       349.0  ...         None     Consult New          0               Old
# 8       349.0  ...         None     Consult New          1               New
# 9       349.0  ...         None     Consult New          0               Old
#
#    user_activity_segment  month  week_start  isfreefollowupavailable  \
# 0          Never Ordered      2  2026-02-13                     true
# 1          Never Ordered      2  2026-02-13                     true
# 2   Dormant_181_365_days      2  2026-02-13                     true
# 3      Churned_>365_days      2  2026-02-13                     true
# 4          Never Ordered      2  2026-02-13                     true
# 5      Churned_>365_days      2  2026-02-13                     true
# 6          Never Ordered      2  2026-02-13                     true
# 7                 Active      2  2026-02-13                     true
# 8          Never Ordered      2  2026-02-13                     true
# 9      Churned_>365_days      2  2026-02-13                     true
#
#    pastconsultationorderid          dt
# 0                           2026-02-16
# 1                           2026-02-16
# 2                           2026-02-16
# 3                           2026-02-16
# 4                           2026-02-16
# 5                           2026-02-16
# 6                           2026-02-16
# 7                           2026-02-16
# 8                           2026-02-16
# 9                           2026-02-16
#
# [10 rows x 53 columns]
